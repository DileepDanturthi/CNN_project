# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.layers import MaxPooling2D, Activation, Convolution2D
from keras.models import Sequential
from keras.layers.convolutional import Conv2D

import numpy as np
import matplotlib.pyplot as plt
import cv2
# Out:
# Using TensorFlow backend.

# %%
! git clone https://github.com/erikreppel/visualizing_cnns
# Out:
# fatal: destination path 'visualizing_cnns' already exists and is not an empty directory.

# %%
cat = cv2.imread('visualizing_cnns/cat.png')

# %%
plt.imshow(cat)

# %%
cat.shape
# Out:
# (320, 400, 3)

# %%
def visualize_cat(model, cat):
    cat_batch=np.expand_dims(cat,axis=0)
    conv_cat=model.predict(cat_batch)
    conv_cat=np.squeeze(conv_cat,axis=0)
    print(conv_cat.shape)
    plt.imshow(conv_cat)

# %%
def nice_cat_printer(model, cat):
    '''prints the cat as a 2d array'''
    cat_batch = np.expand_dims(cat,axis=0)
    conv_cat2 = model.predict(cat_batch)

    conv_cat2 = np.squeeze(conv_cat2, axis=0)
    print(conv_cat2.shape)
    conv_cat2 = conv_cat2.reshape(conv_cat2.shape[:2])

    print(conv_cat2.shape)
    plt.imshow(conv_cat2)

# %%
model = Sequential()
model.add(Convolution2D(1,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=cat.shape))

# Keras expects batches of images, so we have to add a dimension to trick it into being nice
nice_cat_printer(model, cat)
# Out:
# C:\Users\Dileep Danturthi\Anaconda3\envs\myWindowsCV\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(320, 400,...)`
#   """
# (318, 398, 1)
# (318, 398)

# %%
model = Sequential()
model.add(Convolution2D(1,    # number of filter layers
                        15,    # y dimension of kernel (we're going for a 3x3 kernel)
                        15,    # x dimension of kernel
                        input_shape=cat.shape))

nice_cat_printer(model, cat)
# Out:
# C:\Users\Dileep Danturthi\Anaconda3\envs\myWindowsCV\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (15, 15), input_shape=(320, 400,...)`
#   """
# (306, 386, 1)
# (306, 386)

# %%
model = Sequential()
model.add(Convolution2D(1,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=cat.shape))
# Lets add a new activation layer!
model.add(Activation('relu'))

nice_cat_printer(model, cat)
# Out:
# C:\Users\Dileep Danturthi\Anaconda3\envs\myWindowsCV\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(320, 400,...)`
#   """
# (318, 398, 1)
# (318, 398)

# %%
model = Sequential()
model.add(Convolution2D(3,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=cat.shape))
# Lets add a new activation layer!
model.add(Activation('relu'))

visualize_cat(model, cat)
# Out:
# C:\Users\Dileep Danturthi\Anaconda3\envs\myWindowsCV\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(320, 400,...)`
#   """
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (318, 398, 3)

# %%
model = Sequential()
model.add(Convolution2D(1,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=cat.shape))
# Lets add a new max pooling layer!
model.add(MaxPooling2D(pool_size=(5,5)))

nice_cat_printer(model, cat)
# Out:
# C:\Users\Dileep Danturthi\Anaconda3\envs\myWindowsCV\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(320, 400,...)`
#   """
# (63, 79, 1)
# (63, 79)

# %%
model = Sequential()
model.add(Convolution2D(1,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=cat.shape))
# Lets activate then pool!
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(5,5)))

nice_cat_printer(model, cat)
# Out:
# (63, 79, 1)
# (63, 79)
# C:\Users\Dileep Danturthi\Anaconda3\envs\myWindowsCV\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(320, 400,...)`
#   """

# %%
model = Sequential()
model.add(Convolution2D(3,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=cat.shape))
# Lets activate then pool!
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(5,5)))

visualize_cat(model, cat)
# Out:
# C:\Users\Dileep Danturthi\Anaconda3\envs\myWindowsCV\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(320, 400,...)`
#   """
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (63, 79, 3)

# %%
model = Sequential()
model.add(Convolution2D(1,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=cat.shape))
# Lets activate then pool!
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3)))
model.add(Convolution2D(1,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=cat.shape))
# Lets activate then pool!
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3)))

nice_cat_printer(model, cat)
# Out:
# C:\Users\Dileep Danturthi\Anaconda3\envs\myWindowsCV\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(320, 400,...)`
#   """
# C:\Users\Dileep Danturthi\Anaconda3\envs\myWindowsCV\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(320, 400,...)`
#   if sys.path[0] == '':
# (34, 43, 1)
# (34, 43)

# %%
model = Sequential()
model.add(Convolution2D(3,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=cat.shape))
# Lets activate then pool!
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3)))
model.add(Convolution2D(1,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=cat.shape))
# Lets activate then pool!
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

nice_cat_printer(model, cat)
# Out:
# C:\Users\Dileep Danturthi\Anaconda3\envs\myWindowsCV\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(320, 400,...)`
#   """
# C:\Users\Dileep Danturthi\Anaconda3\envs\myWindowsCV\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(320, 400,...)`
#   if sys.path[0] == '':
# (52, 65, 1)
# (52, 65)

# %%
model = Sequential()
model.add(Convolution2D(3,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=cat.shape))
# Lets activate then pool!
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3)))
model.add(Convolution2D(3,    # number of filter layers
                        3,    # y dimension of kernel (we're going for a 3x3 kernel)
                        3,    # x dimension of kernel
                        input_shape=cat.shape))
# Lets activate then pool!
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

visualize_cat(model, cat)
# Out:
# C:\Users\Dileep Danturthi\Anaconda3\envs\myWindowsCV\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(320, 400,...)`
#   """
# C:\Users\Dileep Danturthi\Anaconda3\envs\myWindowsCV\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (3, 3), input_shape=(320, 400,...)`
#   if sys.path[0] == '':
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (52, 65, 3)
